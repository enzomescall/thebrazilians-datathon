# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
import os
path = os.getcwd()
df = pd.read_csv('./US/nmurx_us_19Q1.csv')
df = df.select_dtypes(exclude=["object","float32"])
df= df.fillna(0)
df.columns[512]
# Out:
# 'ILLXCAN_WK'

# %%
Y = df['ILLXCAN_WK'].values
X = df.drop(['ILLXCAN_WK'], axis=1).values
print(Y)
print(X)
# Out:
# [0 0 0 ... 0 0 0]
# [[3.00000000e+00 1.00000000e+00 2.00000000e+00 ... 1.00000000e+00
#   0.00000000e+00 7.07413613e+03]
#  [3.00000000e+00 1.00000000e+00 2.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 4.06946079e+03]
#  [3.00000000e+00 1.00000000e+00 2.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 7.55461812e+03]
#  ...
#  [3.00000000e+00 1.00000000e+00 2.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 2.58199037e+04]
#  [3.00000000e+00 1.00000000e+00 2.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 1.15223774e+04]
#  [3.00000000e+00 1.00000000e+00 2.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 1.18240887e+04]]

# %%
forest = ExtraTreesClassifier(n_estimators=250)

# %%
forest.fit(X,Y)
importances = forest.feature_importances_

# %%
std = np.std([tree.feature_importances_ for tree in forest.estimators_],axis=0)
indices = np.argsort(importances)[::-1]

# %%
# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print(f"{f+1} feature {indices[f]} ({importances[indices[f]]}) {df.columns[indices[f]]}")

# Plot the impurity-based feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
        color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1 feature 511 (0.14088060745302913) ILLXCAN_MNTH
# 2 feature 510 (0.08486413131903293) ILLXCAN_NTY
# 3 feature 516 (0.061610768325049706) ILL_MNTH
# 4 feature 509 (0.059560284187882534) ILLXCAN_YR
# 5 feature 515 (0.0190702537129502) ILL_NTY
# 6 feature 237 (0.011071892823236614) KRAT_USE
# 7 feature 213 (0.010709932382149834) CAN_REC
# 8 feature 514 (0.010133138205479186) ILL_YR
# 9 feature 258 (0.009883175814302009) METHAM_REC
# 10 feature 290 (0.008938484433978848) DAST_2
# 11 feature 508 (0.007408759315394913) ILLXCAN_USE
# 12 feature 239 (0.0072628597148294005) METHAM_USE
# 13 feature 241 (0.007123044837870844) HEROIN_USE
# 14 feature 450 (0.006918251440577479) DAST_SUM
# 15 feature 256 (0.006105260944796852) KRAT_REC
# 16 feature 513 (0.005795973076994902) ILL_USE
# 17 feature 220 (0.005501314986685209) CAN_RSNYR_RELX
# 18 feature 297 (0.005458185244805016) DAST_9
# 19 feature 216 (0.005336784875989052) CAN_FREQ_WK
# 20 feature 275 (0.005255681518594897) KRAT_FIRST
# 21 feature 451 (0.005147527655461279) DAST_CAT
# 22 feature 215 (0.0049706362702271484) CAN_FREQ_MNTH
# 23 feature 295 (0.004959787952006712) DAST_7
# 24 feature 277 (0.004542786883158369) METHAM_FIRST
# 25 feature 279 (0.004522579141739051) HEROIN_FIRST
# 26 feature 240 (0.004296005580995865) NPFENT_USE
# 27 feature 212 (0.004285410671294186) CAN_USE
# 28 feature 260 (0.004283551450933923) HEROIN_REC
# 29 feature 233 (0.003851861838225429) CRACK_USE
# 30 feature 242 (0.003511476963776292) KET_USE
# 31 feature 461 (0.0033158244099286407) SED_NMU
# 32 feature 462 (0.0032540544305477924) SED_NMUYR
# 33 feature 296 (0.0032148360138826984) DAST_8
# 34 feature 298 (0.003075838086838467) DAST_10
# 35 feature 214 (0.002966794167574888) CAN_FIRST
# 36 feature 289 (0.002832232446416739) DAST_1
# 37 feature 252 (0.0027944611636678378) CRACK_REC
# 38 feature 251 (0.0027210906143284048) COKE_REC
# 39 feature 271 (0.0026855123288236954) CRACK_FIRST
# 40 feature 482 (0.002586942147164148) OP_NMU
# 41 feature 455 (0.0025097167694240648) PAINREL_NMUYR
# 42 feature 232 (0.0024953264412452517) COKE_USE
# 43 feature 468 (0.0024383708782744393) STIM_NMU
# 44 feature 219 (0.002316578237382732) CAN_RSNYR_HIGH
# 45 feature 234 (0.0022770285521840085) MDMA_USE
# 46 feature 217 (0.0022753506760956545) CAN_RSNYR_PAIN
# 47 feature 294 (0.0022683726493157507) DAST_6
# 48 feature 278 (0.002266365036560962) NPFENT_FIRST
# 49 feature 221 (0.0022308659535049337) CAN_RSNYR_DOWN
# 50 feature 299 (0.0021934758816049486) TRT_USEYR
# 51 feature 464 (0.002136158618267) SED_NMUMNTH
# 52 feature 259 (0.002106071747413535) NPFENT_REC
# 53 feature 280 (0.0020451503500923665) KET_FIRST
# 54 feature 293 (0.002028083456191739) DAST_5
# 55 feature 261 (0.0020028455079473444) KET_REC
# 56 feature 457 (0.002000761168930949) PAINREL_NMUMNTH
# 57 feature 238 (0.001993612490431162) SPEED_USE
# 58 feature 465 (0.001963604615566642) SED_NMUWK
# 59 feature 255 (0.0019085451597284728) ALKY_REC
# 60 feature 43 (0.001906278097627009) METH_USE
# 61 feature 463 (0.0018717805730597056) SED_NMUNTY
# 62 feature 458 (0.0018511381991181315) PAINREL_NMUWK
# 63 feature 456 (0.0018346794097346241) PAINREL_NMUNTY
# 64 feature 264 (0.0018289979053941773) MUSH_REC
# 65 feature 225 (0.001821739662029784) CAN_TYPEYR_REC
# 66 feature 39 (0.0017352663206044432) GAB_USE
# 67 feature 6 (0.001685268717808232) DEM_INCOME
# 68 feature 253 (0.0016816744251488217) MDMA_REC
# 69 feature 34 (0.0016544128265719262) BUP_USE
# 70 feature 386 (0.001649584345262433) TIME_DEM3
# 71 feature 3 (0.001642238854059081) DEM_AGE
# 72 feature 383 (0.001632492335749817) VMOBILEDEVICE
# 73 feature 429 (0.0016288715392775415) METH_NMU
# 74 feature 291 (0.0016227831074654715) DAST_3
# 75 feature 30 (0.0016134694884781164) ORDER_PAINREL_API_SUF
# 76 feature 353 (0.0016051197884250578) DEM_INSUR
# 77 feature 235 (0.0015952427963875253) GHB_USE
# 78 feature 2 (0.0015919187033526135) DEM_GENDER
# 79 feature 283 (0.0015787579200581216) MUSH_FIRST
# 80 feature 449 (0.0015690056717340914) DEM_AGE10
# 81 feature 270 (0.0015501969375597304) COKE_FIRST
# 82 feature 88 (0.0015492195233327605) ORDER_STIM_API_ATOM
# 83 feature 26 (0.0015480764241302724) ORDER_PAINREL_API_MORPH
# 84 feature 22 (0.0015437025158159079) ORDER_PAINREL_API_HYD
# 85 feature 263 (0.0015342948820688085) LSD_REC
# 86 feature 90 (0.0015285166610865296) ORDER_STIM_API_MOD
# 87 feature 335 (0.0015227949803165322) DEM_MARITAL
# 88 feature 27 (0.0015201233064223495) ORDER_PAINREL_API_OXY
# 89 feature 29 (0.0015199888405072043) ORDER_PAINREL_API_PREG
# 90 feature 454 (0.0015098856399989819) PAINREL_NMU
# 91 feature 50 (0.0015081356956870337) TRAM_USE
# 92 feature 23 (0.0015016849773366312) ORDER_PAINREL_API_HYDM
# 93 feature 370 (0.0014947862750738514) ORDER_ILLICIT_API_METHAM
# 94 feature 487 (0.001492724809663538) GABA_USE
# 95 feature 54 (0.0014890720913968846) ORDER_SED_API_CLOB
# 96 feature 358 (0.001486628943381589) ORDER_OTC_API_DIPH
# 97 feature 388 (0.0014794849938194474) TIME_DEM5
# 98 feature 420 (0.0014755135590072753) FENT_NMU
# 99 feature 14 (0.0014736132812088391) ORDER_THC
# 100 feature 58 (0.0014712908694383608) ORDER_SED_API_EST
# 101 feature 355 (0.0014600433787617364) ORDER_OTC_API_ACE
# 102 feature 10 (0.001456874506717338) TOB_LIFE
# 103 feature 517 (0.0014562773681823945) ILL_WK
# 104 feature 28 (0.001447974044348697) ORDER_PAINREL_API_OXYM
# 105 feature 333 (0.001444757741353232) DEM_RACE_WHITE
# 106 feature 364 (0.0014399644702554452) ORDER_ILLICIT_API_CRACK
# 107 feature 274 (0.0014378761981609387) ALKY_FIRST
# 108 feature 32 (0.001437430023944554) ORDER_PAINREL_API_TRAM
# 109 feature 282 (0.0014365749241376806) LSD_FIRST
# 110 feature 356 (0.0014352001457186487) ORDER_OTC_API_ASP
# 111 feature 66 (0.001428237150458272) ORDER_SED_API_TRI
# 112 feature 372 (0.0014279137621462038) ORDER_ILLICIT_API_HEROIN
# 113 feature 8 (0.0014268417363555758) DEM_GENHEALTH
# 114 feature 61 (0.001426622669408844) ORDER_SED_API_LORA
# 115 feature 375 (0.0014255335467060412) ORDER_ILLICIT_API_LSD
# 116 feature 377 (0.0014246448942237095) ORDER_ILLICIT_API_PCP
# 117 feature 56 (0.0014202822614485056) ORDER_SED_API_CLOR
# 118 feature 389 (0.0014195722503125743) TIME_DEM6
# 119 feature 24 (0.0014184926746237218) ORDER_PAINREL_API_KTM
# 120 feature 361 (0.0014174245455867453) ORDER_OTC_API_NAP
# 121 feature 63 (0.0014124145840162556) ORDER_SED_API_OXA
# 122 feature 87 (0.0014123708965920938) ORDER_STIM_API_AMPH
# 123 feature 55 (0.0014119122721691266) ORDER_SED_API_CLON
# 124 feature 366 (0.0014044089369692557) ORDER_ILLICIT_API_GHB
# 125 feature 395 (0.0014006121476368182) TIME_STIM
# 126 feature 368 (0.0013955276455873606) ORDER_ILLICIT_API_KRAT
# 127 feature 31 (0.0013946286694841593) ORDER_PAINREL_API_TAP
# 128 feature 95 (0.0013874076669652365) ORDER_THC_API_CANN
# 129 feature 62 (0.0013873441197626403) ORDER_SED_API_MID
# 130 feature 57 (0.001384817534986869) ORDER_SED_API_DIA
# 131 feature 379 (0.0013847409697332186) ORDER_ILLICIT_API_SPICE
# 132 feature 60 (0.001378766382952722) ORDER_SED_API_FLUR
# 133 feature 5 (0.0013710022971675489) DEM_REGION
# 134 feature 315 (0.0013639652875177739) MENT_ANYANX
# 135 feature 228 (0.0013636758907989712) CAN_TYPEYR_OTH
# 136 feature 25 (0.0013624504881747266) ORDER_PAINREL_API_METH
# 137 feature 371 (0.0013587679918570512) ORDER_ILLICIT_API_NPFENT
# 138 feature 378 (0.00135693454955027) ORDER_ILLICIT_API_MESC
# 139 feature 89 (0.0013560835080320376) ORDER_STIM_API_MPHEN
# 140 feature 245 (0.0013554411770335323) MUSH_USE
# 141 feature 231 (0.0013554039965777045) ALC_USE
# 142 feature 13 (0.0013527806917339185) ORDER_STIM
# 143 feature 483 (0.0013526538385696808) OP_NMUYR
# 144 feature 396 (0.0013505053626236662) TIME_THC
# 145 feature 15 (0.0013501680704683242) ORDER_PAINREL_API_BHYD
# 146 feature 357 (0.001349797489934948) ORDER_OTC_API_DEX
# 147 feature 338 (0.001341343994192485) DEM_EDU
# 148 feature 91 (0.0013413242230681803) AMPH_USE
# 149 feature 11 (0.0013388051476571849) ORDER_PAINREL
# 150 feature 374 (0.0013386154427596426) ORDER_ILLICIT_API_MEPH
# 151 feature 202 (0.001337800782124415) NAP_USEYR
# 152 feature 390 (0.0013291353444602376) TIME_DEM7
# 153 feature 373 (0.001328232348583097) ORDER_ILLICIT_API_KET
# 154 feature 16 (0.0013281218252200844) ORDER_PAINREL_API_BUP
# 155 feature 488 (0.0013274103040271303) GABA_USEYR
# 156 feature 409 (0.0013224996995302369) CLON_NMU
# 157 feature 4 (0.0013175696349167407) DEM_POSTAL
# 158 feature 12 (0.0013168687810488065) ORDER_SED
# 159 feature 391 (0.0013149930283312373) TIME_DEM8
# 160 feature 59 (0.0013071202143902538) ORDER_SED_API_ESZ
# 161 feature 226 (0.0013070550586903415) CAN_TYPEYR_MED
# 162 feature 9 (0.0013036750178573482) DEM_LIMIT
# 163 feature 382 (0.001302102110263297) QTIME
# 164 feature 369 (0.0013017647233067736) ORDER_ILLICIT_API_SPEED
# 165 feature 273 (0.0013002217404642978) GHB_FIRST
# 166 feature 491 (0.0012993831796804852) GABA_NMUNTY
# 167 feature 363 (0.0012936996939558992) ORDER_ILLICIT_API_COKE
# 168 feature 384 (0.0012916149189160738) TIME_DEM1
# 169 feature 359 (0.0012902002075344033) ORDER_OTC_API_IBU
# 170 feature 328 (0.001289853382392694) DEM_HISPANIC
# 171 feature 67 (0.0012892986531680855) ORDER_SED_API_ZAL
# 172 feature 490 (0.0012873620487388543) GABA_NMUYR
# 173 feature 466 (0.0012853514354064415) STIM_USE
# 174 feature 188 (0.0012849802071962107) ACE_USE
# 175 feature 397 (0.0012845708124494914) DEM_ZIP
# 176 feature 292 (0.0012833352426182268) DAST_4
# 177 feature 385 (0.0012813813633396215) TIME_DEM2
# 178 feature 244 (0.0012719112901592702) LSD_USE
# 179 feature 18 (0.0012694437377873734) ORDER_PAINREL_API_DIHY
# 180 feature 392 (0.0012647125745668898) TIME_DEM9
# 181 feature 51 (0.001264527690923774) ORDER_SED_API_ALP
# 182 feature 35 (0.0012641690372200197) COD_USE
# 183 feature 393 (0.0012625197605838805) TIME_PAINREL
# 184 feature 53 (0.0012605789978304175) ORDER_SED_API_CHL
# 185 feature 381 (0.001259648232739442) ORDER_ILLICIT_API_STER
# 186 feature 65 (0.0012591302447421751) ORDER_SED_API_TEM
# 187 feature 423 (0.0012572879374391224) HYDM_NMU
# 188 feature 272 (0.0012564350337149585) MDMA_FIRST
# 189 feature 376 (0.0012492949789270587) ORDER_ILLICIT_API_MUSH
# 190 feature 365 (0.001244892393534222) ORDER_ILLICIT_API_MDMA
# 191 feature 194 (0.0012431091322133872) NAP_USE
# 192 feature 193 (0.001241034008013311) LOP_USE
# 193 feature 162 (0.0012360145282515169) ALP_NMUYR
# 194 feature 387 (0.0012245674735023122) TIME_DEM4
# 195 feature 249 (0.0012190920756002456) SAL_USE
# 196 feature 20 (0.0012179640279083828) ORDER_PAINREL_API_FENT
# 197 feature 68 (0.001217422483199813) ORDER_SED_API_ZOL
# 198 feature 380 (0.001214296794971691) ORDER_ILLICIT_API_SAL
# 199 feature 7 (0.0012130492087382547) DEM_HOME
# 200 feature 199 (0.001213011492124431) DIPH_USEYR
# 201 feature 473 (0.001212165726264187) THC_USE
# 202 feature 413 (0.001204232487133465) DIA_NMU
# 203 feature 64 (0.001203959800935259) ORDER_SED_API_QUA
# 204 feature 352 (0.0012027955968648136) DEM_EMPLOY
# 205 feature 52 (0.0012025430482288065) ORDER_SED_API_BAC
# 206 feature 19 (0.0011995486924115267) ORDER_PAINREL_API_ELU
# 207 feature 79 (0.0011980037531177457) LORA_USE
# 208 feature 360 (0.0011965515642377285) ORDER_OTC_API_LOP
# 209 feature 96 (0.001195132089380228) ORDER_THC_API_DRON
# 210 feature 196 (0.00119413498204066) ACE_USEYR
# 211 feature 218 (0.001192897403955492) CAN_RSNYR_MED
# 212 feature 309 (0.0011928525322585056) PAIN_CHRONICYR
# 213 feature 41 (0.0011923843363011667) HYDM_USE
# 214 feature 44 (0.0011914777167864115) MORPH_USE
# 215 feature 198 (0.001186564625473064) DEX_USEYR
# 216 feature 287 (0.0011829002523421432) SAL_FIRST
# 217 feature 248 (0.0011811104621654062) SPICE_USE
# 218 feature 236 (0.0011782960104971159) ALKY_USE
# 219 feature 367 (0.0011773795915161124) ORDER_ILLICIT_API_ALKY
# 220 feature 21 (0.0011772013522757963) ORDER_PAINREL_API_GAB
# 221 feature 195 (0.0011726027018479275) OTCOTH_USE
# 222 feature 75 (0.0011692784740996616) DIA_USE
# 223 feature 17 (0.0011660355580850673) ORDER_PAINREL_API_COD
# 224 feature 197 (0.0011623568613622008) ASP_USEYR
# 225 feature 312 (0.0011583635303499687) PAIN_ACUTEYR
# 226 feature 276 (0.0011573776002945955) SPEED_FIRST
# 227 feature 394 (0.0011538864375710072) TIME_SED
# 228 feature 38 (0.0011537453086351347) FENT_USE
# 229 feature 257 (0.001148321749747159) SPEED_REC
# 230 feature 316 (0.0011449923680501592) MENT_ADHD
# 231 feature 97 (0.0011449022996585117) ORDER_THC_API_NAB
# 232 feature 187 (0.0011433632196282226) OTH_RX_DRUG_USE
# 233 feature 208 (0.001138270046110648) IBU_NMUYR
# 234 feature 492 (0.0011371810499640307) GABA_NMUMNTH
# 235 feature 471 (0.0011366534404939302) STIM_NMUMNTH
# 236 feature 230 (0.0011332550465547955) ALC_USEYR
# 237 feature 47 (0.0011328381791974919) PREG_USE
# 238 feature 445 (0.0011210912109496259) TRAM_NMU
# 239 feature 486 (0.001119713632395715) OP_NMUWK
# 240 feature 310 (0.0011071084053118265) PAIN_CHRONICYR_DOC
# 241 feature 190 (0.0011054434325741844) DEX_USE
# 242 feature 200 (0.0011034735328316547) IBU_USEYR
# 243 feature 40 (0.001101732286566972) HYD_USE
# 244 feature 201 (0.0010999313114634758) LOP_USEYR
# 245 feature 189 (0.001096764019282334) ASP_USE
# 246 feature 267 (0.0010921372614839627) SPICE_REC
# 247 feature 425 (0.0010639682257788234) IBU_NMU
# 248 feature 354 (0.0010613871376945819) DEM_HOSPSTAY
# 249 feature 227 (0.001042334411219207) CAN_TYPEYR_HOME
# 250 feature 42 (0.0010368143335202139) KTM_USE
# 251 feature 86 (0.0010322165802982535) ZOL_USE
# 252 feature 460 (0.0010298907889551077) SED_USEYR
# 253 feature 250 (0.0010292192462712498) STER_USE
# 254 feature 459 (0.0010256895792545048) SED_USE
# 255 feature 424 (0.0010162017637010046) HYD_NMU
# 256 feature 411 (0.0010159493396883) COD_NMU
# 257 feature 69 (0.0010125398376953504) ALP_USE
# 258 feature 73 (0.0010080379882652904) CLON_USE
# 259 feature 268 (0.0010045328931088462) SAL_REC
# 260 feature 439 (0.0010024452869294527) OXY_NMU
# 261 feature 311 (0.000996582827728797) PAIN_CHRONICYR_RX
# 262 feature 470 (0.0009939703598114923) STIM_NMUNTY
# 263 feature 331 (0.0009903494004341253) DEM_RACE_BLACK
# 264 feature 327 (0.0009878475831940244) MENT_NONE
# 265 feature 113 (0.0009867510191475387) OXY_USEYR
# 266 feature 344 (0.0009845489969709245) DEM_HEALTH
# 267 feature 300 (0.00098406199078327) TRT_USEYR_ALC
# 268 feature 472 (0.0009821197032692781) STIM_NMUWK
# 269 feature 254 (0.00098002322869121) GHB_REC
# 270 feature 489 (0.000965261348799729) GABA_NMU
# 271 feature 191 (0.000960910622035132) DIPH_USE
# 272 feature 45 (0.0009604477128919481) OXY_USE
# 273 feature 469 (0.0009531855097606302) STIM_NMUYR
# 274 feature 399 (0.0009396525980013464) ALP_NMU
# 275 feature 286 (0.0009384863741880958) SPICE_FIRST
# 276 feature 405 (0.0009331513902869301) BUP_NMU
# 277 feature 269 (0.0009309973204586423) STER_REC
# 278 feature 285 (0.0009287640489130326) MESC_FIRST
# 279 feature 281 (0.000927603524555014) MEPH_FIRST
# 280 feature 108 (0.0009176422540157543) HYD_USEYR
# 281 feature 149 (0.0009173170194338049) FENT_NMUYR
# 282 feature 430 (0.0009134783984194672) MID_NMU
# 283 feature 107 (0.000907069289501673) GAB_USEYR
# 284 feature 398 (0.0009056386038916976) ACE_NMU
# 285 feature 266 (0.0009003826627618192) MESC_REC
# 286 feature 98 (0.0009002565633273454) CANN_USE
# 287 feature 467 (0.0008941190307589751) STIM_USEYR
# 288 feature 192 (0.0008891865313865475) IBU_USE
# 289 feature 401 (0.0008885063893105022) ASP_NMU
# 290 feature 46 (0.0008883977150785197) OXYM_USE
# 291 feature 205 (0.0008852349204941479) ASP_NMUYR
# 292 feature 118 (0.0008831605018200992) TRAM_USEYR
# 293 feature 324 (0.0008786398296291111) MENT_PTSD
# 294 feature 313 (0.0008771303377249382) PAIN_ACUTEYR_DOC
# 295 feature 123 (0.000872940713527225) CLON_USEYR
# 296 feature 224 (0.0008720551230012016) CAN_RSNYR_OTH
# 297 feature 305 (0.0008657426834903729) TRT_DEPYR_BUP
# 298 feature 204 (0.0008627403941216614) ACE_NMUYR
# 299 feature 427 (0.0008599035828852189) LOP_NMU
# 300 feature 120 (0.0008596753032797555) BAC_USEYR
# 301 feature 478 (0.0008547931674605354) THC_NMUMNTH
# 302 feature 111 (0.0008491832335646014) METH_USEYR
# 303 feature 125 (0.0008480899471461123) DIA_USEYR
# 304 feature 103 (0.0008455699772561509) COD_USEYR
# 305 feature 119 (0.0008400619375906711) ALP_USEYR
# 306 feature 243 (0.0008366198993750949) MEPH_USE
# 307 feature 339 (0.0008321806584766991) DEM_STDNT
# 308 feature 453 (0.0008298030076276148) PAINREL_USEYR
# 309 feature 412 (0.0008220653657497339) DEX_NMU
# 310 feature 477 (0.000819799564475047) THC_NMUNTY
# 311 feature 400 (0.000814351508919958) AMPH_NMU
# 312 feature 284 (0.0008115245075352302) PCP_FIRST
# 313 feature 493 (0.0008023499974951285) GABA_NMUWK
# 314 feature 481 (0.0007885125396642549) OP_USEYR
# 315 feature 129 (0.0007856541658094287) LORA_USEYR
# 316 feature 342 (0.0007821376787843118) DEM_VET
# 317 feature 314 (0.0007806041698055667) PAIN_ACUTEYR_RX
# 318 feature 70 (0.0007788577922379136) BAC_USE
# 319 feature 151 (0.0007693126825942572) HYD_NMUYR
# 320 feature 320 (0.0007640885217795005) MENT_DEP
# 321 feature 94 (0.000760311296606542) MOD_USE
# 322 feature 432 (0.0007588620843871078) MORPH_NMU
# 323 feature 99 (0.0007584640565273728) DRON_USE
# 324 feature 265 (0.0007558694905020793) PCP_REC
# 325 feature 346 (0.0007552928199369512) DEM_HEALTH_PRE
# 326 feature 318 (0.0007546406380973415) MENT_BIP
# 327 feature 351 (0.0007543175506029783) DEM_HEALTH_ROLE
# 328 feature 485 (0.0007518459326669273) OP_NMUMNTH
# 329 feature 340 (0.0007499690953509189) DEM_STDNT_PROGRAM
# 330 feature 288 (0.0007459326210593498) STER_FIRST
# 331 feature 343 (0.0007458381660217355) DEM_VET_SERV
# 332 feature 301 (0.0007449670454657618) TRT_USEYR_RX
# 333 feature 93 (0.0007418942665289157) MPHEN_USE
# 334 feature 246 (0.0007402769013007154) PCP_USE
# 335 feature 112 (0.00073961154805278) MORPH_USEYR
# 336 feature 137 (0.0007288641354179795) AMPH_USEYR
# 337 feature 77 (0.0007265357014354953) ESZ_USE
# 338 feature 72 (0.0007264271749682659) CLOB_USE
# 339 feature 402 (0.0007212770300441954) ATOM_NMU
# 340 feature 92 (0.0007174719217848138) ATOM_USE
# 341 feature 203 (0.0007052462627665886) OTCOTH_USEYR
# 342 feature 100 (0.00070375522973135) NAB_USE
# 343 feature 109 (0.0007036931486111813) HYDM_USEYR
# 344 feature 222 (0.0006950680557412694) CAN_RSNYR_WTDR
# 345 feature 476 (0.0006927995858191486) THC_NMUYR
# 346 feature 146 (0.0006917796366024649) COD_NMUYR
# 347 feature 440 (0.0006916053298469319) PREG_NMU
# 348 feature 435 (0.0006856750510064657) NAP_NMU
# 349 feature 474 (0.0006754270504053669) THC_USEYR
# 350 feature 247 (0.0006745055685502859) MESC_USE
# 351 feature 479 (0.0006677729062120932) THC_NMUWK
# 352 feature 304 (0.0006662100006828817) TRT_DEPYR_METH
# 353 feature 448 (0.0006661147755749974) ZOL_NMU
# 354 feature 347 (0.000660857073121027) DEM_HEALTH_HOS
# 355 feature 422 (0.0006527086861435161) GAB_NMU
# 356 feature 36 (0.0006508622867058176) DIHY_USE
# 357 feature 74 (0.0006445895693856141) CLOR_USE
# 358 feature 180 (0.0006408321605648972) AMPH_NMUYR
# 359 feature 319 (0.0006390837674611958) MENT_BPD
# 360 feature 475 (0.0006378583298975019) THC_NMU
# 361 feature 83 (0.0006371382357287031) TEM_USE
# 362 feature 84 (0.000632239509091281) TRI_USE
# 363 feature 480 (0.0006318873401700667) OP_USE
# 364 feature 154 (0.0006309896418401755) METH_NMUYR
# 365 feature 303 (0.0006308373326246741) TRT_USEYR_ILLEGAL
# 366 feature 78 (0.0006285213900261687) FLUR_USE
# 367 feature 484 (0.000621543029798516) OP_NMUNTY
# 368 feature 82 (0.0006202204607736585) QUA_USE
# 369 feature 334 (0.0006174968608651004) DEM_RACE_OTH
# 370 feature 33 (0.0006147064888459914) BHYD_USE
# 371 feature 210 (0.0006126544989229768) NAP_NMUYR
# 372 feature 415 (0.0006115487878569064) DIPH_NMU
# 373 feature 428 (0.0006080792407509171) LORA_NMU
# 374 feature 81 (0.000605442131262188) OXA_USE
# 375 feature 106 (0.0006013975942421143) FENT_USEYR
# 376 feature 156 (0.0006003743760069818) OXY_NMUYR
# 377 feature 322 (0.0005968465810238027) MENT_OCD
# 378 feature 115 (0.0005937249110988418) PREG_USEYR
# 379 feature 102 (0.0005874014699480481) BUP_USEYR
# 380 feature 37 (0.0005867820598794387) ELU_USE
# 381 feature 207 (0.0005860062751881002) DIPH_NMUYR
# 382 feature 71 (0.0005809579745356216) CHL_USE
# 383 feature 135 (0.0005794311588349804) ZAL_USEYR
# 384 feature 229 (0.0005715707156652657) CAN_TYPEYR_UNK
# 385 feature 452 (0.0005695625444231776) PAINREL_USE
# 386 feature 48 (0.0005638629920658621) SUF_USE
# 387 feature 49 (0.0005532310010085105) TAP_USE
# 388 feature 503 (0.0005521442688986243) OXY_NMUNTY
# 389 feature 499 (0.0005461457361414429) HYD_NMUNTY
# 390 feature 433 (0.0005452858189361006) MPHEN_NMU
# 391 feature 80 (0.0005389777023927808) MID_USE
# 392 feature 85 (0.0005388731944951277) ZAL_USE
# 393 feature 438 (0.0005359845324753671) OXYM_NMU
# 394 feature 141 (0.0005355886014930528) CANN_USEYR
# 395 feature 426 (0.0005070134784216153) KTM_NMU
# 396 feature 308 (0.0004994440685934138) TRT_DEPYR_NO
# 397 feature 434 (0.0004938447696692448) NAB_NMU
# 398 feature 406 (0.0004916538124205399) CANN_NMU
# 399 feature 209 (0.0004908996012831625) LOP_NMUYR
# 400 feature 206 (0.00048352869156153465) DEX_NMUYR
# 401 feature 330 (0.00047757986920249676) DEM_RACE_ASIAN
# 402 feature 262 (0.00047598006917145023) MEPH_REC
# 403 feature 110 (0.0004629562597685191) KTM_USEYR
# 404 feature 447 (0.0004624896125162803) ZAL_NMU
# 405 feature 139 (0.00046101444605720163) MPHEN_USEYR
# 406 feature 341 (0.0004602909045665585) DEM_STDNT_UNDER
# 407 feature 326 (0.00045828861546747023) MENT_OTH
# 408 feature 182 (0.00045119679693175074) MPHEN_NMUYR
# 409 feature 150 (0.000448215586258966) GAB_NMUYR
# 410 feature 325 (0.00044427407945247827) MENT_SCH
# 411 feature 114 (0.00044175930302227807) OXYM_USEYR
# 412 feature 166 (0.0004389242992420267) CLON_NMUYR
# 413 feature 345 (0.0004336363752658267) DEM_HEALTH_PRIV
# 414 feature 414 (0.00042861382119799144) DIHY_NMU
# 415 feature 161 (0.00042861001940208666) TRAM_NMUYR
# 416 feature 168 (0.00042485096194462893) DIA_NMUYR
# 417 feature 145 (0.0004247434850709784) BUP_NMUYR
# 418 feature 136 (0.0004239208403463077) ZOL_USEYR
# 419 feature 416 (0.00042029835706120444) DRON_NMU
# 420 feature 317 (0.0004182080250923417) MENT_AUT
# 421 feature 498 (0.00041714782261562713) FENT_NMUNTY
# 422 feature 436 (0.0004162783497311467) OTCOTH_NMU
# 423 feature 323 (0.0004134352386805071) MENT_PPD
# 424 feature 321 (0.00040309501385566294) MENT_EAT
# 425 feature 76 (0.0004028252140993148) EST_USE
# 426 feature 329 (0.0004026362162416102) DEM_RACE_AIAN
# 427 feature 172 (0.0003893912296222553) LORA_NMUYR
# 428 feature 211 (0.0003878599371022191) OTCOTH_NMUYR
# 429 feature 404 (0.00038537874723093275) BHYD_NMU
# 430 feature 446 (0.0003823702592974444) TRI_NMU
# 431 feature 332 (0.0003815725483041461) DEM_RACE_NHPI
# 432 feature 350 (0.0003809567977221468) DEM_HEALTH_OTH
# 433 feature 101 (0.00037752329341671773) BHYD_USEYR
# 434 feature 133 (0.0003767103353511016) TEM_USEYR
# 435 feature 496 (0.0003751974986665644) COD_NMUNTY
# 436 feature 155 (0.00037271820306456177) MORPH_NMUYR
# 437 feature 122 (0.00037266573988312823) CLOB_USEYR
# 438 feature 444 (0.0003697871818766954) TEM_NMU
# 439 feature 184 (0.00036813980787855216) CANN_NMUYR
# 440 feature 140 (0.00036526414897300084) MOD_USEYR
# 441 feature 419 (0.0003649668039919636) ESZ_NMU
# 442 feature 418 (0.00036333037733434924) EST_NMU
# 443 feature 117 (0.0003602197263798662) TAP_USEYR
# 444 feature 403 (0.0003556630079077406) BAC_NMU
# 445 feature 127 (0.0003455196660533034) ESZ_USEYR
# 446 feature 153 (0.0003418068097592026) KTM_NMUYR
# 447 feature 437 (0.0003409491414664897) OXA_NMU
# 448 feature 223 (0.0003331387195044952) CAN_RSNYR_HURT
# 449 feature 142 (0.0003264317734113502) DRON_USEYR
# 450 feature 178 (0.0003201615520363974) ZAL_NMUYR
# 451 feature 183 (0.00031271141128319123) MOD_NMUYR
# 452 feature 158 (0.00031134921096336905) PREG_NMUYR
# 453 feature 152 (0.00031080190944572926) HYDM_NMUYR
# 454 feature 121 (0.00030995945244771515) CHL_USEYR
# 455 feature 443 (0.0003083125647957273) TAP_NMU
# 456 feature 407 (0.00030775554976647605) CHL_NMU
# 457 feature 138 (0.0003063272391162727) ATOM_USEYR
# 458 feature 349 (0.00029842745269646954) DEM_HEALTH_HOME
# 459 feature 421 (0.00029628412566657834) FLUR_NMU
# 460 feature 179 (0.00029471979799600465) ZOL_NMUYR
# 461 feature 1 (0.000289836823056275) QLANG
# 462 feature 143 (0.00028970401958598117) NAB_USEYR
# 463 feature 441 (0.00028948069677048083) QUA_NMU
# 464 feature 501 (0.0002877267428696638) METH_NMUNTY
# 465 feature 431 (0.00028282640380958404) MOD_NMU
# 466 feature 302 (0.00028173152797762117) TRT_USEYR_LEGAL
# 467 feature 185 (0.00027695432160238604) DRON_NMUYR
# 468 feature 410 (0.00027610637795822616) CLOR_NMU
# 469 feature 131 (0.0002737654532105644) OXA_USEYR
# 470 feature 157 (0.00027351226278250274) OXYM_NMUYR
# 471 feature 126 (0.00027179727578005857) EST_USEYR
# 472 feature 497 (0.00027012333057310577) DIHY_NMUNTY
# 473 feature 128 (0.0002691028052363225) FLUR_USEYR
# 474 feature 147 (0.00026573857137618374) DIHY_NMUYR
# 475 feature 442 (0.0002655766960056711) SUF_NMU
# 476 feature 307 (0.00026356387097575573) TRT_DEPYR_OTH
# 477 feature 502 (0.0002625882151693832) MORPH_NMUNTY
# 478 feature 104 (0.0002570032208998686) DIHY_USEYR
# 479 feature 181 (0.00025552825000719933) ATOM_NMUYR
# 480 feature 495 (0.0002540951850259169) BUP_NMUNTY
# 481 feature 134 (0.0002444852296388537) TRI_USEYR
# 482 feature 116 (0.00023812092757731856) SUF_USEYR
# 483 feature 504 (0.00023481960805247379) OXYM_NMUNTY
# 484 feature 417 (0.0002345447552252271) ELU_NMU
# 485 feature 171 (0.00021819581020317107) FLUR_NMUYR
# 486 feature 163 (0.0002133546805814167) BAC_NMUYR
# 487 feature 337 (0.00021045892888660987) DEM_PREG_WK
# 488 feature 160 (0.0002094934900348368) TAP_NMUYR
# 489 feature 507 (0.00020777934925094964) TRAM_NMUNTY
# 490 feature 124 (0.00020478872075794068) CLOR_USEYR
# 491 feature 130 (0.00018488746681421582) MID_USEYR
# 492 feature 173 (0.00018291829657269044) MID_NMUYR
# 493 feature 132 (0.00017510189624777382) QUA_USEYR
# 494 feature 105 (0.00017371484820657363) ELU_USEYR
# 495 feature 170 (0.00016897849140623287) ESZ_NMUYR
# 496 feature 408 (0.00016673058729419147) CLOB_NMU
# 497 feature 336 (0.00016370243594605015) DEM_PREG
# 498 feature 165 (0.00016347942662548376) CLOB_NMUYR
# 499 feature 186 (0.00015171711156060897) NAB_NMUYR
# 500 feature 175 (0.00014334916846445706) QUA_NMUYR
# 501 feature 506 (0.0001418450725845184) TAP_NMUNTY
# 502 feature 167 (0.0001313814417419281) CLOR_NMUYR
# 503 feature 512 (0.00012621428226722796) ILLXCAN_WK
# 504 feature 177 (0.00012471024920590306) TRI_NMUYR
# 505 feature 500 (0.00012215731405742106) HYDM_NMUNTY
# 506 feature 148 (0.00011786765967330081) ELU_NMUYR
# 507 feature 348 (0.00011276515965871479) DEM_HEALTH_OUT
# 508 feature 494 (0.00011096261083643348) BHYD_NMUNTY
# 509 feature 144 (0.00010780695158224683) BHYD_NMUYR
# 510 feature 159 (0.00010398863740515171) SUF_NMUYR
# 511 feature 306 (9.39733162094352e-05) TRT_DEPYR_HER
# 512 feature 176 (9.357903686102551e-05) TEM_NMUYR
# 513 feature 174 (9.025537452036856e-05) OXA_NMUYR
# 514 feature 505 (5.157990026046091e-05) SUF_NMUNTY
# 515 feature 169 (3.5583671105973305e-05) EST_NMUYR
# 516 feature 164 (3.202010017216905e-05) CHL_NMUYR
# 517 feature 362 (0.0) ORDER_OTC_API_OTCOTH
# 518 feature 0 (0.0) STATUS

# %%
log = LogisticRegression(max_iter = 50000)
log.fit(X,Y)
# Out:
# C:\Users\chave\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=50000)

# %%
importance = model_coef_[0]
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-382e4a742dbb> in <module>
# ----> 1 importance = model_coef_[0]
#       2 # summarize feature importance
#       3 for i,v in enumerate(importance):
#       4         print('Feature: %0d, Score: %.5f' % (i,v))
#       5 # plot feature importance
#
# NameError: name 'model_coef_' is not defined

# %%
decision = DecisionTreeClassifier()
decision.fit(X,Y)
feat_importance = decision.tree_.compute_feature_importances(normalize=False)
for i in range(X.shape[1]):
    if feat_importance[i] != 0:
        print(f"Feature {i} {feat_importance[i]} {df.columns[i]}")
# Out:
# Feature 3 9.772007897405408e-05 DEM_AGE
# Feature 11 0.00013668976444727125 ORDER_PAINREL
# Feature 13 0.00010712014193418804 ORDER_STIM
# Feature 19 6.0927116713278095e-05 ORDER_PAINREL_API_ELU
# Feature 26 4.463339247257836e-05 ORDER_PAINREL_API_MORPH
# Feature 31 0.00015050066724964147 ORDER_PAINREL_API_TAP
# Feature 43 0.0002416456061114693 METH_USE
# Feature 57 5.021256653165065e-05 ORDER_SED_API_DIA
# Feature 58 0.00023969238370811127 ORDER_SED_API_EST
# Feature 60 0.0001104676463696314 ORDER_SED_API_FLUR
# Feature 61 4.463339247257836e-05 ORDER_SED_API_LORA
# Feature 82 0.00011167844584628116 QUA_USE
# Feature 84 5.7385790321886474e-05 TRI_USE
# Feature 139 9.663333742132301e-05 MPHEN_USEYR
# Feature 215 5.021256653165065e-05 CAN_FREQ_MNTH
# Feature 216 0.0007481170692785572 CAN_FREQ_WK
# Feature 224 1.64550323514413e-05 CAN_RSNYR_OTH
# Feature 252 5.951118996343781e-05 CRACK_REC
# Feature 253 0.00011351631543778299 MDMA_REC
# Feature 255 0.00018959695334362265 ALKY_REC
# Feature 256 6.344737416802141e-05 KRAT_REC
# Feature 258 0.0005361229813684599 METHAM_REC
# Feature 344 0.0001477378857223034 DEM_HEALTH
# Feature 358 5.021256653165065e-05 ORDER_OTC_API_DIPH
# Feature 366 0.0001004251330633013 ORDER_ILLICIT_API_GHB
# Feature 370 6.485789843671542e-05 ORDER_ILLICIT_API_METHAM
# Feature 371 0.00014877797490859453 ORDER_ILLICIT_API_NPFENT
# Feature 373 3.347504435443377e-05 ORDER_ILLICIT_API_KET
# Feature 388 0.00015680951028419925 TIME_DEM5
# Feature 389 7.74708169345468e-05 TIME_DEM6
# Feature 392 7.810843682701215e-05 TIME_DEM9
# Feature 393 3.227950705606117e-05 TIME_PAINREL
# Feature 394 6.5356038977704e-05 TIME_SED
# Feature 450 7.970248655817568e-05 DAST_SUM
# Feature 455 5.8581327620259095e-05 PAINREL_NMUYR
# Feature 462 0.00023861113055368753 SED_NMUYR
# Feature 488 0.0002921458416386947 GABA_USEYR
# Feature 503 4.463339247257836e-05 OXY_NMUNTY
# Feature 511 0.018374006168388246 ILLXCAN_MNTH
# Feature 516 0.007082468455089409 ILL_MNTH
