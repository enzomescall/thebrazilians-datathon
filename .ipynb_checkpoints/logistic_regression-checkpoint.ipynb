# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
import os
path = os.getcwd()

# %%
df = pd.read_csv('./US/nmurx_us_19Q1.csv')

train, test = train_test_split(df, test_size=0.2)

# %%
train[]
# Out:
#                       DATE  STATUS  QLANG  DEM_GENDER  DEM_AGE  DEM_POSTAL  \
# 1489   2019-03-27 12:52:33       3      1           2       60          23
# 22041  2019-03-12 04:15:28       3      1           2       57         296
# 24883  2019-03-31 16:48:00       3      1           1       71         923
# 2571   2019-04-03 11:47:07       3      1           1       28         105
# 5992   2019-04-01 06:14:39       3      1           1       63         601
# ...                    ...     ...    ...         ...      ...         ...
# 8014   2019-05-12 00:33:39       3      2           2       31         951
# 13857  2019-04-10 19:09:43       3      1           1       35         797
# 6588   2019-03-28 15:47:41       3      1           2       55         440
# 11315  2019-04-07 10:53:42       3      1           1       59         339
# 10205  2019-03-19 23:39:31       3      1           2       40         132
#
#        DEM_REGION  DEM_INCOME  DEM_HOME  DEM_GENHEALTH  ...  ILLXCAN_YR  \
# 1489            1           5         4              5  ...           0
# 22041           3           2         2              2  ...           0
# 24883           4           2         2              5  ...           0
# 2571            1           5         3              4  ...           0
# 5992            2           5         3              3  ...           0
# ...           ...         ...       ...            ...  ...         ...
# 8014            4           4         3              5  ...           0
# 13857           3           1         1              4  ...           0
# 6588            2           2         2              3  ...           0
# 11315           3           3         2              3  ...           1
# 10205           1           2         5              3  ...           0
#
#        ILLXCAN_NTY  ILLXCAN_MNTH  ILLXCAN_WK  ILL_USE  ILL_YR  ILL_NTY  \
# 1489             0             0           0        1       1        1
# 22041            0             0           0        0       0        0
# 24883            0             0           0        0       0        0
# 2571             0             0           0        1       0        0
# 5992             0             0           0        0       0        0
# ...            ...           ...         ...      ...     ...      ...
# 8014             0             0           0        0       0        0
# 13857            0             0           0        1       1        1
# 6588             0             0           0        0       0        0
# 11315            0             0           0        1       1        0
# 10205            0             0           0        0       0        0
#
#        ILL_MNTH  ILL_WK            WT
# 1489          1       0   7375.900937
# 22041         0       0   4819.917439
# 24883         0       0   8419.973992
# 2571          0       0   8301.432466
# 5992          0       0   9043.867973
# ...         ...     ...           ...
# 8014          0       0   4651.781616
# 13857         0       0   4383.877938
# 6588          0       0   7907.339676
# 11315         0       0   3189.400632
# 10205         0       0  10269.068597
#
# [23898 rows x 523 columns]

# %%
len(test)
# Out:
# 5975

# %%
len(df)
# Out:
# 29873
